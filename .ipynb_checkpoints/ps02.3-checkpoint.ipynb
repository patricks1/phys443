# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams
from astropy import constants as c
from astropy import units as u

# %%
rcParams['mathtext.fontset'] = 'dejavuserif'
rcParams['font.family'] = 'serif' 
rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['axes.grid']=True
rcParams['axes.titlesize']=24
rcParams['axes.labelsize']=20
rcParams['axes.titlepad']=15
rcParams['legend.frameon'] = True
rcParams['legend.facecolor']='white'
rcParams['legend.fontsize']=18

# %% [markdown]
# ## #3.a

# %%
H=70*u.km/u.s/u.Mpc
vc=2.*np.pi*8.3*u.kpc/(250.*u.Myr)
r200=vc/(10.*H)
print vc.to(u.km/u.hr)
print vc.to(u.km/u.s)
print r200.to(u.kpc)
# Out:
# 734289.014617 km / h
# 203.969170727 km / s
# 291.38452961 kpc

# %% [markdown]
# ## #3.c

# %%
m200=vc**3./H/c.G/10.
print m200.to(u.M_sun)
# Out:
# 2.81860658211e+12 solMass

# %% [markdown]
# ## #3.d

# %%
def a_f(z):
    a=1./(1.+z)
    return a

def H_f(H0,z):
    omega_m=0.3
    omega_l=0.7
    a=a_f(z)
    Hz=np.sqrt(H0**2.*((1.-omega_m-omega_l)*a**(-2.)+omega_m*a**(-3.)+omega_l))
    #Hz=H0*(1.+z)*np.sqrt(1+omega_m*z)
    return Hz

def r200_f(vc,H0,z):
    omega_m=0.3
    Hz=H_f(H0,z)
    r200=vc/(10.*Hz)
    return r200.to(u.kpc)

def m200_f(vc,H0,z):
    omega_m=0.3
    Hz=H_f(H0,z)
    m200=vc**3./(10.*c.G*Hz)
    return m200.to(u.M_sun)

vc_vish=230*u.km/u.s
print r200_f(vc,H,1.)
print m200_f(vc,H,1.)
# Out:
# 165.495291908 kpc
# 1.60086096439e+12 solMass

# %% [markdown]
# ## #3.e

# %%
def rho_c_f(H0,z):
    Hz=H_f(H0,z)
    rho_c=3.*Hz**2.\
          /(8.*np.pi*c.G)
    return rho_c.to(u.M_sun/u.Mpc**3.)

zs=np.linspace(0.,10.,100)

fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.semilogy(zs,200.*rho_c_f(H,zs))
ax.set_ylabel('$200\\rho_\mathrm{crit}(z)\ /\ [\mathrm{M}_\odot\cdot\mathrm{Mpc}^{-3}]$')
ax.set_xlabel('z')
ax.set_title('$200\\rho_\mathrm{c}$ as a function of redshift',pad=30)
plt.show()

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111)
ax.semilogy(zs,H_f(H,zs))
plt.show()
